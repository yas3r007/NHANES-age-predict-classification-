# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("NHANES_age_prediction.csv")
data.head()
# Out:
#       SEQN age_group  RIDAGEYR  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  \
# 0  73564.0     Adult      61.0       2.0     2.0    35.7   110.0     2.0
# 1  73568.0     Adult      26.0       2.0     2.0    20.3    89.0     2.0
# 2  73576.0     Adult      16.0       1.0     2.0    23.2    89.0     2.0
# 3  73577.0     Adult      32.0       1.0     2.0    28.9   104.0     2.0
# 4  73580.0     Adult      38.0       2.0     1.0    35.9   103.0     2.0
#
#    LBXGLT  LBXIN
# 0   150.0  14.91
# 1    80.0   3.85
# 2    68.0   6.14
# 3    84.0  16.15
# 4    81.0  10.92

# %%
data.columns=["SEQUENCE","AGE GROUP","AGE","GENDER","ACTIVITY","BMI","GLUCOSE","DIABETIC","ORAL","INSULIN"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278 entries, 0 to 2277
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SEQUENCE   2278 non-null   float64
#  1   AGE GROUP  2278 non-null   object
#  2   AGE        2278 non-null   float64
#  3   GENDER     2278 non-null   float64
#  4   ACTIVITY   2278 non-null   float64
#  5   BMI        2278 non-null   float64
#  6   GLUCOSE    2278 non-null   float64
#  7   DIABETIC   2278 non-null   float64
#  8   ORAL       2278 non-null   float64
#  9   INSULIN    2278 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 178.1+ KB

# %%
data.columns
# Out:
# Index(['SEQUENCE', 'AGE GROUP', 'AGE', 'GENDER', 'ACTIVITY', 'BMI', 'GLUCOSE',
#        'DIABETIC', 'ORAL', 'INSULIN'],
#       dtype='object')

# %%
data["SEQUENCE"].nunique()
# Out:
# 2278

# %%
data.drop(columns=["SEQUENCE"],inplace=True)

# %%
data
# Out:
#      AGE GROUP   AGE  GENDER  ACTIVITY   BMI  GLUCOSE  DIABETIC   ORAL  \
# 0        Adult  61.0     2.0       2.0  35.7    110.0       2.0  150.0
# 1        Adult  26.0     2.0       2.0  20.3     89.0       2.0   80.0
# 2        Adult  16.0     1.0       2.0  23.2     89.0       2.0   68.0
# 3        Adult  32.0     1.0       2.0  28.9    104.0       2.0   84.0
# 4        Adult  38.0     2.0       1.0  35.9    103.0       2.0   81.0
# ...        ...   ...     ...       ...   ...      ...       ...    ...
# 2273     Adult  38.0     2.0       2.0  33.5    100.0       2.0   73.0
# 2274     Adult  61.0     1.0       2.0  30.0     93.0       2.0  208.0
# 2275     Adult  34.0     1.0       2.0  23.7    103.0       2.0  124.0
# 2276     Adult  60.0     2.0       2.0  27.4     90.0       2.0  108.0
# 2277     Adult  26.0     1.0       2.0  24.5    108.0       2.0  108.0
#
#       INSULIN
# 0       14.91
# 1        3.85
# 2        6.14
# 3       16.15
# 4       10.92
# ...       ...
# 2273     6.53
# 2274    13.02
# 2275    21.41
# 2276     4.99
# 2277     3.76
#
# [2278 rows x 9 columns]

# %%
data["AGE GROUP"].unique()
# Out:
# array(['Adult', 'Senior'], dtype=object)

# %%
data["AGE"].unique()
# Out:
# array([61., 26., 16., 32., 38., 50., 14., 57., 75., 43., 54., 36., 80.,
#        71., 67., 70., 25., 24., 30., 44., 12., 58., 77., 29., 53., 46.,
#        48., 56., 15., 31., 13., 35., 21., 39., 62., 59., 63., 34., 72.,
#        64., 65., 47., 66., 51., 27., 37., 41., 42., 49., 20., 40., 22.,
#        17., 60., 28., 79., 52., 23., 19., 18., 68., 33., 45., 74., 78.,
#        55., 73., 69., 76.])

# %%
data["GENDER"].unique()
# Out:
# array([2., 1.])

# %%
data["ACTIVITY"].unique()
# Out:
# array([2., 1., 7.])

# %%
data["BMI"].unique()
# Out:
# array([35.7, 20.3, 23.2, 28.9, 35.9, 23.6, 38.7, 38.3, 38.9, 32.7, 27.3,
#        24.6, 30.5, 30.3, 22.1, 37.8, 28. , 46.1, 21. , 33. , 29.1, 32.3,
#        37.6, 36.4, 18. , 33.6, 21.4, 18.9, 26.4, 26.5, 19.2, 36.2, 22.5,
#        27.5, 25.6, 37.5, 39.7, 21.1, 19. , 23.4, 20.6, 18.1, 30.2, 24.9,
#        23. , 49.9, 32.2, 27.8, 26.3, 25. , 28.6, 19.7, 22.6, 41.1, 19.5,
#        50.9, 28.1, 30.7, 30.8, 42.1, 21.5, 26.6, 22.2, 29.4, 32.4, 30.9,
#        32. , 29.7, 24.2, 22.4, 26.8, 39.2, 31.9, 31.2, 25.4, 24.5, 18.4,
#        23.5, 26.2, 39. , 35. , 35.6, 42.7, 23.7, 23.9, 29.9, 47.2, 34.2,
#        40.7, 24.3, 37. , 28.7, 36.1, 26.9, 14.5, 29.5, 21.3, 21.9, 49.2,
#        30.6, 33.3, 31.6, 19.8, 31.8, 16.8, 28.2, 45.1, 31. , 27.6, 30.4,
#        39.8, 47.7, 22.7, 29.6, 33.9, 21.8, 24.4, 34.7, 37.1, 20.9, 44.9,
#        26.1, 28.3, 47.8, 27.9, 31.4, 43.1, 33.2, 28.5, 21.7, 38.5, 48.6,
#        25.8, 27.2, 29. , 15.9, 43.2, 36.8, 25.1, 25.2, 24. , 51.3, 30. ,
#        34. , 43.3, 32.6, 21.6, 18.6, 44.1, 32.5, 44.6, 31.5, 20.8, 26.7,
#        40. , 29.2, 29.3, 20.5, 15.7, 33.8, 41. , 33.4, 32.8, 27. , 33.1,
#        34.6, 34.8, 18.2, 45.7, 38.8, 17.1, 20. , 27.7, 29.8, 32.1, 17.9,
#        31.3, 68.6, 35.1, 42.2, 31.1, 27.1, 27.4, 19.1, 54. , 35.8, 50.2,
#        17.3, 20.7, 37.2, 19.6, 22.8, 32.9, 23.8, 34.3, 23.3, 14.6, 24.8,
#        24.7, 33.7, 28.4, 46.4, 42.4, 25.5, 19.3, 48.3, 17.6, 37.4, 36. ,
#        35.5, 43.6, 34.5, 24.1, 50.7, 21.2, 16.5, 39.9, 41.4, 20.4, 33.5,
#        22. , 36.5, 35.3, 16.9, 25.7, 41.5, 42. , 20.1, 55.6, 20.2, 54.9,
#        36.7, 25.3, 37.7, 25.9, 22.3, 50.5, 26. , 40.1, 47.5, 50.4, 19.9,
#        17.7, 35.4, 18.8, 34.1, 23.1, 17.5, 50.8, 22.9, 17.8, 45.3, 43.8,
#        38.4, 39.4, 17.2, 17.4, 30.1, 28.8, 16.1, 70.1, 63. , 41.3, 40.4,
#        44. , 44.8, 40.6, 15.4, 18.5, 43.4, 44.4, 42.3, 18.3, 56.7, 40.2,
#        39.3, 34.4, 39.5, 37.3, 50.3, 50.6, 41.9, 31.7, 48.2, 49.3, 47.1,
#        48.4, 57.9, 46.8, 45.9, 36.3, 38. , 38.2, 47.3, 41.8, 40.8, 56.9,
#        48.7, 17. , 44.2, 41.2, 45.5, 36.9, 43.7, 38.6, 46.3, 42.9, 47.6,
#        15.3, 36.6, 58.7, 58.4, 60.9, 39.6, 54.2, 51.9, 41.7, 18.7, 52.6,
#        51.1, 52.2, 37.9, 43.5, 51.4, 40.5, 42.8, 46.7, 19.4, 16.7, 52. ,
#        49. , 67.5, 56.3, 53. , 16.2, 34.9, 16.6, 50. , 35.2, 48. ])

# %%
data["GLUCOSE"].unique()
# Out:
# array([110.,  89., 104., 103.,  94., 107.,  90.,  98.,  85., 100., 102.,
#        133., 114.,  96., 139.,  86., 108.,  99., 105.,  87.,  95.,  88.,
#        111.,  93.,  83.,  69., 112., 129.,  79., 119., 120.,  92., 118.,
#        115., 101.,  81., 106., 142., 125., 109.,  91.,  97.,  84.,  82.,
#         73.,  80., 123.,  72., 159., 117., 124., 297., 208., 122., 127.,
#        116.,  74., 113.,  75., 135.,  77., 175., 156., 138., 131., 121.,
#        250., 134., 128.,  78., 126., 137., 166., 257., 140., 136., 275.,
#        150., 210., 130., 223., 195., 147., 405., 183.,  70.,  63.,  68.,
#         66., 149., 179., 368., 188., 220.,  76.,  67., 155., 160., 132.,
#        158., 333.])

# %%
data["DIABETIC"].unique()
# Out:
# array([2., 1., 3.])

# %%
data["ORAL"].unique()
# Out:
# array([150.,  80.,  68.,  84.,  81., 100., 202., 164., 113.,  95.,  91.,
#         97., 124., 295., 120.,  82., 154.,  77., 160.,  72.,  76.,  83.,
#        158.,  78.,  67., 142., 145., 184.,  79., 171.,  93., 106., 122.,
#        170.,  86., 185.,  74.,  85.,  98.,  96., 138., 121.,  88., 109.,
#        155., 203., 136.,  55., 134., 159., 192., 108.,  90., 103., 117.,
#        137., 123.,  89., 215., 143., 101., 147., 110.,  92., 178.,  64.,
#        119., 201., 152.,  71., 176.,  94., 193., 131.,  65., 104.,  62.,
#        130., 151., 249.,  44., 107.,  99., 141., 175., 320., 139., 132.,
#         87., 126., 148., 102.,  63.,  69.,  51., 112.,  58., 225., 116.,
#        161., 473., 129., 315., 140., 105., 111.,  75., 135., 173., 252.,
#        114., 169., 128.,  73.,  66., 163., 115.,  60., 219., 149., 181.,
#         41.,  47., 118., 162., 125., 127., 209.,  70.,  46., 179., 236.,
#        190., 146., 188., 182., 177., 199., 157., 180., 316., 311.,  57.,
#        233., 207., 168., 156.,  52., 226., 205., 200., 234., 187., 196.,
#        204., 352., 211., 189., 133.,  49., 153., 250., 195., 166.,  48.,
#        144., 294., 197., 411.,  59., 308.,  42., 186., 198., 167., 267.,
#        210., 174., 228., 427., 214.,  54.,  45., 274., 266., 194.,  53.,
#        280., 459., 265., 216.,  56., 183., 256., 242., 241., 222., 604.,
#        165., 318.,  43., 218., 296., 172., 245.,  61., 224., 284.,  40.,
#        248., 346., 304., 312., 503., 221., 395., 217.,  50., 206., 235.,
#        279., 240., 332., 220., 213., 288., 243., 229., 287., 231., 510.,
#        208.])

# %%
data["INSULIN"].unique()
# Out:
# array([14.91,  3.85,  6.14, ..., 13.91, 21.41,  3.76])

# %%
data["AGE GROUP"].value_counts()
# Out:
# AGE GROUP
# Adult     1914
# Senior     364
# Name: count, dtype: int64

# %%
data["AGE"].value_counts()
# Out:
# AGE
# 80.0    107
# 16.0     70
# 18.0     70
# 14.0     60
# 12.0     58
#        ...
# 76.0     13
# 75.0     12
# 77.0      9
# 79.0      8
# 78.0      8
# Name: count, Length: 69, dtype: int64

# %%
data["GENDER"].value_counts()
# Out:
# GENDER
# 2.0    1165
# 1.0    1113
# Name: count, dtype: int64

# %%
data["ACTIVITY"].value_counts()
# Out:
# ACTIVITY
# 2.0    1868
# 1.0     409
# 7.0       1
# Name: count, dtype: int64

# %%
data["BMI"].value_counts()
# Out:
# BMI
# 23.9    26
# 23.7    24
# 27.4    22
# 25.8    22
# 24.2    21
#         ..
# 44.8     1
# 63.0     1
# 39.7     1
# 17.8     1
# 48.0     1
# Name: count, Length: 340, dtype: int64

# %%
data["GLUCOSE"].value_counts()
# Out:
# GLUCOSE
# 96.0     119
# 94.0     118
# 99.0     106
# 100.0    102
# 95.0      99
#         ...
# 175.0      1
# 72.0       1
# 159.0      1
# 297.0      1
# 333.0      1
# Name: count, Length: 101, dtype: int64

# %%
data["DIABETIC"].value_counts()
# Out:
# DIABETIC
# 2.0    2199
# 3.0      58
# 1.0      21
# Name: count, dtype: int64

# %%
data["ORAL"].value_counts()
# Out:
# ORAL
# 91.0     43
# 100.0    40
# 94.0     39
# 103.0    36
# 90.0     36
#          ..
# 242.0     1
# 241.0     1
# 222.0     1
# 604.0     1
# 208.0     1
# Name: count, Length: 232, dtype: int64

# %%
data["INSULIN"].value_counts()
# Out:
# INSULIN
# 6.61     8
# 5.04     7
# 6.50     6
# 6.75     6
# 4.86     6
#         ..
# 13.73    1
# 5.95     1
# 15.03    1
# 6.64     1
# 3.76     1
# Name: count, Length: 1424, dtype: int64

# %%
data.head()
# Out:
#   AGE GROUP   AGE  GENDER  ACTIVITY   BMI  GLUCOSE  DIABETIC   ORAL  INSULIN
# 0     Adult  61.0     2.0       2.0  35.7    110.0       2.0  150.0    14.91
# 1     Adult  26.0     2.0       2.0  20.3     89.0       2.0   80.0     3.85
# 2     Adult  16.0     1.0       2.0  23.2     89.0       2.0   68.0     6.14
# 3     Adult  32.0     1.0       2.0  28.9    104.0       2.0   84.0    16.15
# 4     Adult  38.0     2.0       1.0  35.9    103.0       2.0   81.0    10.92

# %%
data.columns
# Out:
# Index(['AGE GROUP', 'AGE', 'GENDER', 'ACTIVITY', 'BMI', 'GLUCOSE', 'DIABETIC',
#        'ORAL', 'INSULIN'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# AGE GROUP    0
# AGE          0
# GENDER       0
# ACTIVITY     0
# BMI          0
# GLUCOSE      0
# DIABETIC     0
# ORAL         0
# INSULIN      0
# dtype: int64

# %%
def plot_boxplot(data,ft):
    data.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
def outliers(data,ft):
    Q1=data[ft].quantile(0.25)
    Q3=data[ft].quantile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR

    ls=data.index[ (data[ft] < lower_bound) | (data[ft]> upper_bound) ]

    return ls

# %%
index_list=[]
for feature in ['AGE', 'GENDER', 'ACTIVITY', 'BMI', 'GLUCOSE', 'DIABETIC','ORAL', 'INSULIN']:
    index_list.extend(outliers(data,feature))
index_list
# Out:
# [4,
#  9,
#  11,
#  15,
#  23,
#  31,
#  36,
#  39,
#  47,
#  50,
#  62,
#  72,
#  75,
#  80,
#  89,
#  94,
#  98,
#  100,
#  107,
#  109,
#  121,
#  132,
#  134,
#  155,
#  169,
#  176,
#  177,
#  181,
#  182,
#  188,
#  189,
#  197,
#  201,
#  211,
#  214,
#  217,
#  222,
#  223,
#  230,
#  233,
#  241,
#  247,
#  251,
#  254,
#  264,
#  266,
#  269,
#  274,
#  278,
#  281,
#  285,
#  288,
#  293,
#  295,
#  302,
#  305,
#  313,
#  320,
#  321,
#  329,
#  343,
#  350,
#  351,
#  352,
#  360,
#  363,
#  374,
#  377,
#  379,
#  381,
#  383,
#  384,
#  389,
#  396,
#  397,
#  412,
#  413,
#  435,
#  440,
#  443,
#  450,
#  455,
#  474,
#  478,
#  479,
#  480,
#  483,
#  488,
#  490,
#  491,
#  508,
#  513,
#  522,
#  523,
#  526,
#  533,
#  543,
#  545,
#  564,
#  572,
#  575,
#  584,
#  593,
#  595,
#  597,
#  613,
#  620,
#  621,
#  623,
#  627,
#  628,
#  630,
#  632,
#  635,
#  650,
#  654,
#  669,
#  673,
#  688,
#  691,
#  710,
#  712,
#  713,
#  717,
#  726,
#  728,
#  730,
#  737,
#  741,
#  746,
#  755,
#  765,
#  766,
#  774,
#  789,
#  790,
#  793,
#  795,
#  798,
#  800,
#  810,
#  822,
#  823,
#  826,
#  827,
#  830,
#  837,
#  838,
#  840,
#  847,
#  851,
#  858,
#  873,
#  883,
#  886,
#  887,
#  892,
#  895,
#  898,
#  906,
#  911,
#  915,
#  925,
#  934,
#  944,
#  945,
#  950,
#  958,
#  966,
#  971,
#  977,
#  990,
#  1016,
#  1021,
#  1026,
#  1049,
#  1052,
#  1081,
#  1085,
#  1096,
#  1097,
#  1099,
#  1107,
#  1114,
#  1117,
#  1118,
#  1119,
#  1127,
#  1135,
#  1137,
#  1141,
#  1142,
#  1144,
#  1145,
#  1147,
#  1156,
#  1161,
#  1165,
#  1170,
#  1184,
#  1192,
#  1197,
#  1201,
#  1213,
#  1218,
#  1231,
#  1235,
#  1237,
#  1241,
#  1242,
#  1246,
#  1249,
#  1251,
#  1254,
#  1275,
#  1277,
#  1282,
#  1290,
#  1294,
#  1297,
#  1305,
#  1306,
#  1308,
#  1309,
#  1318,
#  1320,
#  1321,
#  1325,
#  1327,
#  1328,
#  1330,
#  1333,
#  1337,
#  1344,
#  1352,
#  1353,
#  1362,
#  1368,
#  1373,
#  1384,
#  1389,
#  1397,
#  1400,
#  1406,
#  1414,
#  1416,
#  1418,
#  1420,
#  1424,
#  1427,
#  1428,
#  1430,
#  1439,
#  1440,
#  1443,
#  1447,
#  1454,
#  1461,
#  1462,
#  1463,
#  1464,
#  1473,
#  1479,
#  1482,
#  1483,
#  1487,
#  1488,
#  1491,
#  1492,
#  1502,
#  1506,
#  1511,
#  1514,
#  1516,
#  1520,
#  1530,
#  1533,
#  1537,
#  1541,
#  1543,
#  1545,
#  1550,
#  1554,
#  1555,
#  1556,
#  1559,
#  1565,
#  1575,
#  1584,
#  1588,
#  1589,
#  1603,
#  1604,
#  1611,
#  1613,
#  1638,
#  1645,
#  1649,
#  1652,
#  1653,
#  1655,
#  1665,
#  1670,
#  1675,
#  1677,
#  1680,
#  1707,
#  1708,
#  1710,
#  1728,
#  1729,
#  1734,
#  1744,
#  1766,
#  1776,
#  1789,
#  1804,
#  1811,
#  1812,
#  1816,
#  1820,
#  1825,
#  1827,
#  1830,
#  1835,
#  1836,
#  1837,
#  1839,
#  1842,
#  1849,
#  1853,
#  1861,
#  1863,
#  1870,
#  1871,
#  1874,
#  1884,
#  1885,
#  1891,
#  1892,
#  1900,
#  1904,
#  1913,
#  1914,
#  1921,
#  1926,
#  1930,
#  1934,
#  1935,
#  1950,
#  1953,
#  1956,
#  1963,
#  1965,
#  1971,
#  1980,
#  1982,
#  1984,
#  1987,
#  1995,
#  1996,
#  2000,
#  2002,
#  2005,
#  2010,
#  2015,
#  2016,
#  2020,
#  2021,
#  2024,
#  2026,
#  2027,
#  2051,
#  2054,
#  2055,
#  2060,
#  2062,
#  2065,
#  2068,
#  2070,
#  2071,
#  2073,
#  2074,
#  2076,
#  2077,
#  2088,
#  2095,
#  2106,
#  2108,
#  2113,
#  2127,
#  2131,
#  2139,
#  2142,
#  2159,
#  2160,
#  2164,
#  2165,
#  2170,
#  2180,
#  2197,
#  2199,
#  2202,
#  2215,
#  2218,
#  2220,
#  2239,
#  2241,
#  2246,
#  2257,
#  18,
#  50,
#  63,
#  101,
#  121,
#  133,
#  141,
#  153,
#  158,
#  172,
#  193,
#  209,
#  212,
#  265,
#  291,
#  305,
#  309,
#  357,
#  367,
#  394,
#  398,
#  459,
#  504,
#  530,
#  550,
#  558,
#  561,
#  575,
#  582,
#  662,
#  679,
#  704,
#  814,
#  821,
#  829,
#  837,
#  898,
#  904,
#  919,
#  982,
#  983,
#  1019,
#  1026,
#  1030,
#  1056,
#  1112,
#  1119,
#  1120,
#  1199,
#  1242,
#  1276,
#  1329,
#  1337,
#  1355,
#  1385,
#  1405,
#  1435,
#  1444,
#  1447,
#  1460,
#  1485,
#  1498,
#  1504,
#  1542,
#  1630,
#  1670,
#  1678,
#  1700,
#  1772,
#  1774,
#  1792,
#  1795,
#  1804,
#  1860,
#  1917,
#  1924,
#  1965,
#  1972,
#  1977,
#  2011,
#  2049,
#  2057,
#  2067,
#  2068,
#  2093,
#  2203,
#  2244,
#  2258,
#  14,
#  18,
#  44,
#  55,
#  93,
#  95,
#  162,
#  163,
#  167,
#  205,
#  208,
#  212,
#  232,
#  367,
#  395,
#  444,
#  465,
#  470,
#  504,
#  537,
#  559,
#  575,
#  580,
#  609,
#  624,
#  664,
#  686,
#  703,
#  781,
#  784,
#  794,
#  799,
#  818,
#  835,
#  841,
#  847,
#  853,
#  901,
#  929,
#  938,
#  952,
#  983,
#  1007,
#  1013,
#  1016,
#  1068,
#  1073,
#  1076,
#  1081,
#  1097,
#  1100,
#  1102,
#  1113,
#  1115,
#  1120,
#  1147,
#  1167,
#  1224,
#  1234,
#  1244,
#  1276,
#  1297,
#  1298,
#  1312,
#  1313,
#  1356,
#  1441,
#  1465,
#  1478,
#  1483,
#  1486,
#  1507,
#  1522,
#  1529,
#  1546,
#  1547,
#  1626,
#  1630,
#  1644,
#  1659,
#  1708,
#  1739,
#  1758,
#  1763,
#  1794,
#  1799,
#  1875,
#  1879,
#  1892,
#  1965,
#  1971,
#  2022,
#  2050,
#  2055,
#  2068,
#  2084,
#  2096,
#  2158,
#  2173,
#  2184,
#  2203,
#  2220,
#  2246,
#  2253,
#  123,
#  143,
#  157,
#  162,
#  208,
#  223,
#  239,
#  245,
#  252,
#  280,
#  295,
#  305,
#  341,
#  364,
#  381,
#  383,
#  426,
#  470,
#  475,
#  505,
#  515,
#  535,
#  555,
#  579,
#  609,
#  623,
#  624,
#  630,
#  663,
#  714,
#  717,
#  719,
#  741,
#  781,
#  821,
#  853,
#  901,
#  936,
#  945,
#  980,
#  1081,
#  1092,
#  1115,
#  1138,
#  1147,
#  1224,
#  1236,
#  1328,
#  1390,
#  1430,
#  1447,
#  1466,
#  1482,
#  1529,
#  1542,
#  1547,
#  1577,
#  1581,
#  1605,
#  1630,
#  1638,
#  1644,
#  1681,
#  1739,
#  1753,
#  1819,
#  1840,
#  1855,
#  1868,
#  1878,
#  1892,
#  2014,
#  2068,
#  2080,
#  2084,
#  2123,
#  2128,
#  2184,
#  2214,
#  6,
#  14,
#  55,
#  82,
#  93,
#  113,
#  149,
#  163,
#  200,
#  208,
#  212,
#  252,
#  297,
#  341,
#  364,
#  395,
#  402,
#  444,
#  465,
#  470,
#  481,
#  512,
#  556,
#  557,
#  569,
#  575,
#  580,
#  588,
#  591,
#  609,
#  612,
#  623,
#  696,
#  699,
#  708,
#  786,
#  794,
#  799,
#  807,
#  808,
#  816,
#  818,
#  841,
#  853,
#  873,
#  896,
#  902,
#  909,
#  912,
#  938,
#  945,
#  952,
#  983,
#  1013,
#  1016,
#  1041,
#  1060,
#  1068,
#  1076,
#  1081,
#  1091,
#  1095,
#  1100,
#  1115,
#  1120,
#  1130,
#  1138,
#  1143,
#  1147,
#  1167,
#  1187,
#  1224,
#  1244,
#  1276,
#  1305,
#  1311,
#  1313,
#  1323,
#  1390,
#  1399,
#  1437,
#  1441,
#  1465,
#  1483,
#  1486,
#  1507,
#  1529,
#  1547,
#  1630,
#  1637,
#  1644,
#  1659,
#  1728,
#  1733,
#  1739,
#  1753,
#  1758,
#  1763,
#  1784,
#  1844,
#  1868,
#  1879,
#  1892,
#  1906,
#  1937,
#  1971,
#  2030,
#  2050,
#  2068,
#  2076,
#  2084,
#  2096,
#  2122,
#  2128,
#  2143,
#  2184,
#  2196,
#  2220,
#  2221,
#  2253,
#  2274,
#  18,
#  60,
#  63,
#  67,
#  80,
#  90,
#  95,
#  153,
#  154,
#  156,
#  167,
#  181,
#  198,
#  200,
#  209,
#  232,
#  237,
#  247,
#  248,
#  265,
#  281,
#  291,
#  305,
#  309,
#  323,
#  337,
#  357,
#  361,
#  382,
#  402,
#  417,
#  421,
#  424,
#  441,
#  443,
#  462,
#  482,
#  494,
#  497,
#  533,
#  558,
#  575,
#  580,
#  581,
#  588,
#  679,
#  689,
#  696,
#  704,
#  709,
#  731,
#  741,
#  754,
#  757,
#  783,
#  801,
#  838,
#  841,
#  847,
#  892,
#  899,
#  901,
#  902,
#  904,
#  919,
#  945,
#  963,
#  982,
#  984,
#  995,
#  1013,
#  1030,
#  1033,
#  1054,
#  1069,
#  1071,
#  1076,
#  1083,
#  1112,
#  1120,
#  1147,
#  1168,
#  1170,
#  1232,
#  1234,
#  1243,
#  1275,
#  1276,
#  1288,
#  1312,
#  1318,
#  1323,
#  1329,
#  1336,
#  1337,
#  1375,
#  1381,
#  1385,
#  1390,
#  1424,
#  1426,
#  1443,
#  1444,
#  1485,
#  1504,
#  1509,
#  1520,
#  1539,
#  1542,
#  1556,
#  1562,
#  1580,
#  1597,
#  1630,
#  1644,
#  1649,
#  1679,
#  1689,
#  1723,
#  1739,
#  1763,
#  1770,
#  1779,
#  1806,
#  1819,
#  1822,
#  1829,
#  1841,
#  1871,
#  1901,
#  1917,
#  1920,
#  1967,
#  1972,
#  1977,
#  2011,
#  2023,
#  2039,
#  2053,
#  2067,
#  2068,
#  2084,
#  2093,
#  2156,
#  2196,
#  2199,
#  2237,
#  2246,
#  2255,
#  2258]

# %%
#def remove(data,ls):
#   ls=sorted(set(ls))
#   data=data.drop(ls)
#   return data

# %%
#data_cleaned=remove(data,index_list)

# %%
data["AGE GROUP"]=data["AGE GROUP"].replace({"Adult":1,"Senior":0})

# %%
data["AGE GROUP"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data[["BMI","GLUCOSE","INSULIN","ORAL"]].skew()
# Out:
# BMI        1.333223
# GLUCOSE    7.190189
# INSULIN    2.782750
# ORAL       2.874792
# dtype: float64

# %%
from scipy.stats import boxcox
data["BMI"],a=boxcox(data["BMI"])
data["GLUCOSE"],c=boxcox(data["GLUCOSE"])

# %%
data[["BMI","GLUCOSE"]].skew()
# Out:
# BMI        0.006194
# GLUCOSE   -0.204942
# dtype: float64

# %%
from scipy.stats import boxcox
data["INSULIN"],a=boxcox(data["INSULIN"])
data["ORAL"],c=boxcox(data["ORAL"])

# %%
data[["INSULIN","ORAL"]].skew()
# Out:
# INSULIN   -0.000820
# ORAL      -0.034389
# dtype: float64

# %%
data.skew()
# Out:
# AGE GROUP   -1.858216
# AGE          0.237167
# GENDER      -0.045696
# ACTIVITY    -0.543589
# BMI          0.006194
# GLUCOSE     -0.204942
# DIABETIC     2.282147
# ORAL        -0.034389
# INSULIN     -0.000820
# dtype: float64

# %%
from scipy.stats import boxcox
data["DIABETIC"],c=boxcox(data["DIABETIC"])

# %%
data[["DIABETIC"]].skew()
# Out:
# DIABETIC    0.452031
# dtype: float64

# %%
data.skew()
# Out:
# AGE GROUP   -1.858216
# AGE          0.237167
# GENDER      -0.045696
# ACTIVITY    -0.543589
# BMI          0.006194
# GLUCOSE     -0.204942
# DIABETIC     0.452031
# ORAL        -0.034389
# INSULIN     -0.000820
# dtype: float64

# %%
X=data.drop("AGE GROUP",axis=1)
y=data["AGE GROUP"]

# %%
Train=[]
Test=[]
CV=[]
for i in range(0,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)

    from sklearn.linear_model import LogisticRegression
    log_default=LogisticRegression()
    log_default.fit(X_train,y_train)

    ypred_train=log_default.predict(X_train)
    ypred_test=log_default.predict(X_test)

    from sklearn.metrics import accuracy_score
    Train.append(accuracy_score(y_train,ypred_train))
    Test.append(accuracy_score(y_test,ypred_test))

    from sklearn.model_selection import cross_val_score
    CV.append(cross_val_score(log_default,X_train,y_train,cv=5,scoring="accuracy").mean())

em=pd.DataFrame({"Train":Train,"Test":Test,"CV":CV})
gm=em[(abs(em["Train"]-em["Test"])<=0.05) & (abs(em["Test"]-em["CV"])<=0.05)]
rs=gm[gm["CV"]==gm["CV"].max()].index.to_list()[0]
print("Best random_state number:",rs)
# Out:
# Best random_state number: 0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=rs)

# %%
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
ypred_train=log_reg.predict(X_train)

from sklearn.metrics import accuracy_score
print("Train accuracy:",accuracy_score(y_train,ypred_train))

from sklearn.model_selection import cross_val_score
print("CV Score:",cross_val_score(log_reg,X_train,y_train,cv=5,scoring="accuracy").mean())

ypred_test=log_reg.predict(X_test)
print("Test accuracy:",accuracy_score(y_test,ypred_test))
# Out:
# Train accuracy: 0.9994511525795828
# CV Score: 1.0
# Test accuracy: 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier
estimator=KNeighborsClassifier()
param_grid={'n_neighbors':list(range(1,50))}

from sklearn.model_selection import GridSearchCV
knn_grid=GridSearchCV(estimator,param_grid,cv=5,scoring='accuracy')
knn_grid.fit(X_train,y_train)

knn_model=knn_grid.best_estimator_

y_pred_train=knn_model.predict(X_train)
y_pred_test=knn_model.predict(X_test)

from sklearn.metrics import accuracy_score
print("train accuracy:",accuracy_score(y_train,y_pred_train))
print("test accuracy:",accuracy_score(y_test,y_pred_test))

from sklearn.model_selection import cross_val_score
print("Cross Validation Score:",cross_val_score(knn_model,X_train,y_train,cv=5,scoring="accuracy").mean())
# Out:
# train accuracy: 1.0
# test accuracy: 1.0
# Cross Validation Score: 1.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

estimator=SVC()
param_grid={'C':[0.01,0.1,1,10,100],'kernel':['linear','rbf','sigmoid','poly']}

svm_grid=GridSearchCV(estimator,param_grid,scoring="accuracy",cv=5)
svm_grid.fit(X_train,y_train)

svm_model=svm_grid.best_estimator_

y_pred_train=svm_model.predict(X_train)
y_pred_test=svm_model.predict(X_test)

print("Train accuracy:",accuracy_score(y_train,ypred_train))
print("Cross validation score:",cross_val_score(svm_model,X_train,y_train,cv=5,scoring="accuracy").mean())
print("Test accuracy:",accuracy_score(y_test,ypred_test))
# Out:
# Train accuracy: 0.9994511525795828
# Cross validation score: 1.0
# Test accuracy: 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
estimator=DecisionTreeClassifier(random_state=rs)
param_grid={"criterion":["gini","entropy"],
            "max_depth":list(range(1,16))}
from sklearn.model_selection import GridSearchCV
dt_grid=GridSearchCV(estimator,param_grid,scoring="accuracy",cv=5)
dt_grid.fit(X_train,y_train)

dt=dt_grid.best_estimator_

dt_fi=dt.feature_importances_

index=[i for i,x in enumerate(dt_fi) if x>0]

X_train_dt=X_train.iloc[:,index]
X_test_dt=X_test.iloc[:,index]

dt.fit(X_train_dt,y_train)

ypred_train=dt.predict(X_train_dt)
ypred_test=dt.predict(X_test_dt)

print("Train Accuracy:",accuracy_score(y_train,ypred_train))
print("Cross validation score:",cross_val_score(dt,X_train_dt,y_train,cv=5,scoring="accuracy").mean())
print("Test accuracy:",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy: 1.0
# Cross validation score: 1.0
# Test accuracy: 1.0

# %%
X_train_dt
# Out:
#        AGE
# 1627  18.0
# 2190  68.0
# 924   80.0
# 302   48.0
# 638   80.0
# ...    ...
# 1033  16.0
# 1731  43.0
# 763   25.0
# 835   28.0
# 1653  15.0
#
# [1822 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
estimator=RandomForestClassifier(random_state=rs)
param_grid={"n_estimators":list(range(1,51))}

from sklearn.model_selection import GridSearchCV
rf_grid=GridSearchCV(estimator,param_grid,scoring="accuracy",cv=5)
rf_grid.fit(X_train,y_train)

rf=rf_grid.best_estimator_
rf_fi=rf.feature_importances_

index=[i for i,x in enumerate(rf_fi) if x>0]

X_train_rf=X_train.iloc[:,index]
X_test_rf=X_test.iloc[:,index]

rf.fit(X_train_rf,y_train)

ypred_train=rf.predict(X_train_rf)
ypred_test=rf.predict(X_test_rf)

print("Train Accuracy:",accuracy_score(y_train,ypred_train))
print("Cross validation score:",cross_val_score(rf,X_train_rf,y_train,cv=5,scoring="accuracy").mean())
print("Test accuracy:",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy: 1.0
# Cross validation score: 1.0
# Test accuracy: 1.0

# %%
from sklearn.ensemble import AdaBoostClassifier
estimator=AdaBoostClassifier(random_state=rs)
param_grid={"n_estimators":list(range(1,51))}

from sklearn.model_selection import GridSearchCV
ab_grid=GridSearchCV(estimator,param_grid,scoring="accuracy",cv=5)
ab_grid.fit(X_train,y_train)

ab=ab_grid.best_estimator_
ab_fi=ab.feature_importances_

index=[i for i,x in enumerate(ab_fi) if x>0]

X_train_ab=X_train.iloc[:,index]
X_test_ab=X_test.iloc[:,index]

ab.fit(X_train_ab,y_train)

ypred_train=ab.predict(X_train_ab)
ypred_test=ab.predict(X_test_ab)

print("Train Accuracy:",accuracy_score(y_train,ypred_train))
print("Cross validation score:",cross_val_score(ab,X_train_ab,y_train,cv=5,scoring="accuracy").mean())
print("Test accuracy:",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy: 1.0
# Cross validation score: 1.0
# Test accuracy: 1.0

# %%
from sklearn.ensemble import GradientBoostingClassifier
estimator= GradientBoostingClassifier(random_state=rs)
param_grid={"n_estimators":list(range(1,10)),"learning_rate":[0.1,0.2,0.3,0.5,0.8,1]}

from sklearn.model_selection import GridSearchCV
gb_grid=GridSearchCV(estimator,param_grid,scoring="accuracy",cv=5)
gb_grid.fit(X_train,y_train)

gb=gb_grid.best_estimator_
gb_fi=gb.feature_importances_

index=[i for i,x in enumerate(gb_fi) if x>0]

X_train_gb=X_train.iloc[:,index]
X_test_gb=X_test.iloc[:,index]

gb.fit(X_train_gb,y_train)

ypred_train=gb.predict(X_train_gb)
ypred_test=gb.predict(X_test_gb)

print("Train Accuracy:",accuracy_score(y_train,ypred_train))
print("Cross validation score:",cross_val_score(gb,X_train_gb,y_train,cv=5,scoring="accuracy").mean())
print("Test accuracy:",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy: 1.0
# Cross validation score: 1.0
# Test accuracy: 1.0

# %%
from xgboost import XGBClassifier
estimator= XGBClassifier(random_state=rs)
param_grid={"n_estimators":[10,20,40,100],"max_depth":[3,4,5],"gamma":[0,0.15,0.3,0.5,1]}

from sklearn.model_selection import GridSearchCV
xgb_grid=GridSearchCV(estimator,param_grid,scoring="accuracy",cv=5)
xgb_grid.fit(X_train,y_train)

xgb=xgb_grid.best_estimator_
xgb_fi=xgb.feature_importances_

index=[i for i,x in enumerate(xgb_fi) if x>0]

X_train_xgb=X_train.iloc[:,index]
X_test_xgb=X_test.iloc[:,index]

xgb.fit(X_train_xgb,y_train)

ypred_train=xgb.predict(X_train_xgb)
ypred_test=xgb.predict(X_test_xgb)

print("Train Accuracy:",accuracy_score(y_train,ypred_train))
print("Cross validation score:",cross_val_score(xgb,X_train_xgb,y_train,cv=5,scoring="accuracy").mean())
print("Test accuracy:",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy: 1.0
# Cross validation score: 1.0
# Test accuracy: 1.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from keras.models import Sequential
ann=Sequential()

# %%
from keras.layers import Dense

ann.add(Dense(input_dim=8,units=6,kernel_initializer="uniform",activation="relu"))
ann.add(Dense(units=6,kernel_initializer="uniform",activation="relu"))
ann.add(Dense(units=1,kernel_initializer="uniform",activation="sigmoid"))

ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
ann.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7899 - loss: 0.6875
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8348 - loss: 0.6508
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8295 - loss: 0.5457
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8247 - loss: 0.4093
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8526 - loss: 0.2922
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9034 - loss: 0.2393
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1972
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9592 - loss: 0.1686
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9513 - loss: 0.1559
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9656 - loss: 0.1369
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9716 - loss: 0.1119
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9784 - loss: 0.0941
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9828 - loss: 0.0805
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0800
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9879 - loss: 0.0687
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9882 - loss: 0.0625
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9880 - loss: 0.0607
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9914 - loss: 0.0527
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9900 - loss: 0.0527
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0498
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9933 - loss: 0.0481
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9917 - loss: 0.0442
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.0400
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9943 - loss: 0.0365
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9907 - loss: 0.0393
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9943 - loss: 0.0323
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0317
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9932 - loss: 0.0342
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0339
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.0273
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9961 - loss: 0.0272
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9963 - loss: 0.0249
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9968 - loss: 0.0269
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9958 - loss: 0.0291
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9954 - loss: 0.0231
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9929 - loss: 0.0302
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0263
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0234
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9982 - loss: 0.0223
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9969 - loss: 0.0224
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0202
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9976 - loss: 0.0187
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0196
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9961 - loss: 0.0189
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9990 - loss: 0.0205
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9964 - loss: 0.0222
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9968 - loss: 0.0215
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0198
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0183
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9986 - loss: 0.0186
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9955 - loss: 0.0185
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0160
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9981 - loss: 0.0162
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9998 - loss: 0.0159
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0170
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.0158
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9988 - loss: 0.0175
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.0154
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9992 - loss: 0.0140
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9997 - loss: 0.0136
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0151
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0126
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9980 - loss: 0.0150
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9993 - loss: 0.0149
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9997 - loss: 0.0119
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9986 - loss: 0.0138
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9974 - loss: 0.0142
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9998 - loss: 0.0121
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0142
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9997 - loss: 0.0113
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9999 - loss: 0.0104
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9995 - loss: 0.0102
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0134
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0140
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9973 - loss: 0.0144
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9986 - loss: 0.0116
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0133
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9995 - loss: 0.0099
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9999 - loss: 0.0098
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0122
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.0098
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.0144
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9986 - loss: 0.0092
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9997 - loss: 0.0084
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0110
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.0113
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9981 - loss: 0.0105
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9988 - loss: 0.0118
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9995 - loss: 0.0095
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9993 - loss: 0.0101
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0097
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0075
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9995 - loss: 0.0106
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0084
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0099
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9992 - loss: 0.0080
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9992 - loss: 0.0110
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9999 - loss: 0.0085
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0089

# %%
y_pred=ann.predict(X_test)
y_pred=(y_pred>0.5)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

print("Test Accuracy:",accuracy_score(y_test,y_pred))
confusion_matrix(y_test,y_pred)
# Out:
# Test Accuracy: 1.0
# array([[ 73,   0],
#        [  0, 383]], dtype=int64)
